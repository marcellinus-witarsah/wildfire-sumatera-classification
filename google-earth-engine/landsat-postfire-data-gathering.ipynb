# %%
#import necessary libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import urllib

# %% [markdown]
# # Display Data about All Wildfire Incidents in Indonesia
# Gather information for all wildfire events in Sumatra

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

os.chdir("C:\\Users\\USER\\Documents\\DATA USER\\DATA D\\skripsi-uph\\wildfire-data-science")
os.getcwd()

wf_data  = pd.read_csv("data-total.csv")
# rename columns
wf_data.rename(
    columns={
        'Lat': 'lat', 
        'Long': 'long', 
        'Satellite': 'satellite', 
        'Time_UTC': 'time_utc', 
        'Date': 'date', 
        'Source': 'source', 
        'PROVINSI': 'provinsi',
        'KAB_KOTA': 'kab_kota',
        }, 
    inplace=True
    )

wf_data.date = pd.to_datetime(wf_data.date, format="%Y%m%d")
wf_data.date = wf_data.date.astype('string')

# %%
# All provinces in sumatera
sumatera_provinces = [
    'SUMATERA UTARA',
    'JAMBI',
    'RIAU',
    'SUMATERA BARAT',
    'SUMATERA SELATAN',
    'BENGKULU',
    'LAMPUNG',
    'ACEH',
    ]
# create filter so that only events in sumatera will be returned.
sumatera_filter = wf_data['provinsi'].apply(lambda x: x in sumatera_provinces) 
sumatera_only = wf_data.loc[sumatera_filter]

display(sumatera_only.info())
display(sumatera_only.provinsi.unique())
display(sumatera_only.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7839 entries, 1 to 39670
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        7839 non-null   float64
#  1   long       7839 non-null   float64
#  2   satellite  7839 non-null   object
#  3   time_utc   7839 non-null   object
#  4   date       7839 non-null   string
#  5   source     7839 non-null   object
#  6   provinsi   7839 non-null   object
#  7   kab_kota   7839 non-null   object
#  8   kec2006    7830 non-null   object
#  9   desaa2006  7830 non-null   object
#  10  nama_kaw   930 non-null    object
# dtypes: float64(2), object(8), string(1)
# memory usage: 734.9+ KB
# None
# array(['LAMPUNG', 'RIAU', 'SUMATERA UTARA', 'SUMATERA BARAT',
#        'SUMATERA SELATAN', 'ACEH', 'JAMBI', 'BENGKULU'], dtype=object)
#        lat     long satellite     time_utc        date source        provinsi  \
# 1 -5.06259  105.101   LPN-NPP  06:11:04 AM  2016-08-24  LAPAN         LAMPUNG
# 4  1.18991  100.672   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN            RIAU
# 5  2.31418  100.288   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN  SUMATERA UTARA
# 6  1.41833  100.752   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN            RIAU
# 8  1.38958  100.673   LPN-NPP  06:36:36 AM  2016-09-13  LAPAN            RIAU
#
#          kab_kota              kec2006              desaa2006 nama_kaw
# 1  LAMPUNG TENGAH            ANAK TUHA              BUMI JAYA      NaN
# 4      ROKAN HULU  KECAMATAN KAPENUHAN  UPT SP IV KOTO TENGAH      NaN
# 5     LABUHANBATU         PANAI TENGAH           SELAT BETING      NaN
# 6     ROKAN HILIR      KECAMATAN PUJUD          SIARANG ARANG      NaN
# 8     ROKAN HILIR      KECAMATAN PUJUD           TELUK NAYANG      NaN

# %%
# changing the date data type to datetime
# Adding date day, month, and year to the data frame


# if 'year' not in sumatera_only.columns.values:
#     date_formatted = sumatera_only['date'].astype('datetime64[ns]')
#     date = pd.DatetimeIndex(sumatera_only['date'])
#     sumatera_only.insert(len(sumatera_only.columns), "year", date.year, True) # adding column
#     sumatera_only.insert(len(sumatera_only.columns), "month", date.month, True) # adding column
#     sumatera_only.insert(len(sumatera_only.columns), "day", date.day, True) # adding column

# %%
sumatera_only = sumatera_only.sort_values(by=['date'], 
                                          ascending=True,
                                          ignore_index=True)
sumatera_only
# Out:
#            lat        long satellite     time_utc        date source  \
# 0     1.649680  100.892000   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN
# 1     1.648530  100.884000   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN
# 2     1.580030  100.855000   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN
# 3     4.272360   97.747800   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN
# 4     1.656640  100.891000   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN
# ...        ...         ...       ...          ...         ...    ...
# 7834 -4.437215  104.505066   LPN-NPP  12:44:37 PM  2020-09-16  LAPAN
# 7835  0.785336   99.191719   LPN-NPP  13:04:01 PM  2020-10-17  LAPAN
# 7836 -0.470491  100.017670   LPN-NPP  13:04:01 PM  2020-10-17  LAPAN
# 7837  1.306781   99.927521   LPN-NPP  13:04:01 PM  2020-10-17  LAPAN
# 7838  0.593332  101.315201   LPN-NPP  13:16:47 PM  2020-10-27  LAPAN
#
#             provinsi         kab_kota                  kec2006  \
# 0               RIAU      ROKAN HILIR  KECAMATAN BANGKO PUSAKO
# 1               RIAU      ROKAN HILIR  KECAMATAN BANGKO PUSAKO
# 2               RIAU      ROKAN HILIR    KECAMATAN TANAH PUTIH
# 3               ACEH     ACEH TAMIANG             TAMIANG HULU
# 4               RIAU      ROKAN HILIR  KECAMATAN BANGKO PUSAKO
# ...              ...              ...                      ...
# 7834         LAMPUNG         WAYKANAN          BLAMBANGAN UMPU
# 7835  SUMATERA UTARA  MANDAILINGNATAL                    NATAL
# 7836  SUMATERA BARAT   PADANGPARIAMAN             BATANG GASAN
# 7837  SUMATERA UTARA     PADANG LAWAS           BARUMUN TENGAH
# 7838            RIAU           KAMPAR         KECAMATAN TAPUNG
#
#                desaa2006 nama_kaw
# 0         SUNGAI MENASIB      NaN
# 1         SUNGAI MENASIB      NaN
# 2         BALAM SEMPURNA      NaN
# 3          BATU BEDULANG      NaN
# 4         SUNGAI MENASIB      NaN
# ...                  ...      ...
# 7834  TANJUNG RAYA GIHAM      NaN
# 7835      PARDAMEAN BARU      NaN
# 7836         MALAI BAWAH      NaN
# 7837            SIPAGABU      NaN
# 7838        RUMBAI BUKIT      NaN
#
# [7839 rows x 11 columns]

# %% [markdown]
# # Import earth engine API which is called ee

# %%
import ee
import folium
from folium import plugins

# %%
# Authenticate earth engine servers
ee.Authenticate()

#initialize API
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=D88US6LljhlhtVdAppGeySmVc9k35mAE04_6V_4ix54&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=D88US6LljhlhtVdAppGeySmVc9k35mAE04_6V_4ix54&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AX4XfWgrd7AA7AhBnv-xqeehRA_In0niXABHaTuEdKtLdmvpL75DP8deeEM
#
# Successfully saved authorization token.

# %% [markdown]
# # Download Landsat Sattelite Image

# %%
def cloudMask2(image):
    scored = ee.Algorithms.Landsat.simpleCloudScore(image)
    return image.updateMask(scored.select(['cloud']).lt(20))\
                .addBands(image.metadata('system:time_start'))


def download_landsat_satellite_image(
        satellite_name, situation, 
        dataset, scale, file_format, 
        folder_path):
    
    for row in range(len(dataset)):
        file_path = os.path.join(folder_path, str(row))
        if os.path.exists(file_path):
            print("data already exist")
            
        else:
            os.mkdir(file_path)
        
        os.chdir(file_path)
        print(os.getcwd())
        # Set coordinates
        print(f"row {row} requesting...")
        coordinates = [float(dataset.lat.values[row]), float(dataset.long.values[row])]
        region = ee.Geometry.Rectangle([coordinates[1]-0.2, coordinates[0]-0.2, 
                                        coordinates[1]+0.2, coordinates[0]+0.2]);


        # filter image collection
        # set base date
        base_date = ee.Date(dataset.date.values[row])

        # set geometry point
        point = ee.Geometry.Point(dataset.long.values[row], dataset.lat.values[row])

        # pre fire
        prefire_date_start = ee.Date(base_date.advance(-365, 'day'))
        prefire_date_end = ee.Date(base_date.advance(-1, 'day'))

        # sentinel image pre wildfire event
        prefire_collection = ee.ImageCollection(satellite_name)\
                                   .filterDate(prefire_date_start, prefire_date_end)\
                                   .filterBounds(region)\
                                   .map(cloudMask2)\
                                   .median()

        # Calculate NBR for pre fire
        pre_nbr = prefire_collection.normalizedDifference(['B5', 'B7'])


        # post fire
        postfire_date_start = ee.Date(base_date.advance(1, 'day'))
        postfire_date_end = ee.Date(base_date.advance(365, 'day'))

        # sentinel image post wildfire event
        postfire_collection = ee.ImageCollection(satellite_name)\
                                   .filterDate(postfire_date_start, postfire_date_end)\
                                   .filterBounds(region)\
                                   .map(cloudMask2)\
                                   .median()

        # Calculate NBR for post fire
        post_nbr = postfire_collection.normalizedDifference(['B5', 'B7'])

        # calculate delta NBR
        delta_nbr = pre_nbr.subtract(post_nbr).rename('DELTA_NBR')
        postfire_collection = postfire_collection.addBands(delta_nbr)
        
        if situation == 'prefire':
            filenames= ['b7_b5','b4_b3','b2']
            bands =  [
                ['B7', 'B5'], 
                ['B4', 'B3'], 
                ['B2'],
                ]
            
            for i in range(len(filenames)):
                if filenames[i] not in os.listdir():
                    download_url = prefire_collection.getDownloadURL({
                        'region': region,
                        'bands' : bands[i],
                        'scale' : scale,
                        'format': file_format
                    })
                    
                    print(f"download data from {download_url}")
                    urllib.request.urlretrieve(download_url, filenames[i])
                    print(f"{download_url} downloaded")
                
                else:
                    print(f"{bands[i]} already exist")
                    
        else:
            filenames= ['dnbr_b7','b5_b4','b3_b2']
            bands =  [
                ['DELTA_NBR', 'B7'], 
                ['B5', 'B4'], 
                ['B3', 'B2'],
                ]

            for i in range(len(filenames)):
                if filenames[i] not in os.listdir():
                    download_url = postfire_collection.getDownloadURL({
                        'region': region,
                        'bands' : bands[i],
                        'scale' : scale,
                        'format': file_format
                    })

                    print(f"download data from {download_url}")
                    urllib.request.urlretrieve(download_url, filenames[i])
                    print(f"{download_url} downloaded")
                else:
                    print(f"{bands[i]} already exist")

# %% [markdown]
# # Define variable to store directory of folders for downloading

# %%
D_DIR = "D:\\"

WILDFIRE_SUMATERA_DATASET_DIR = "wildfire-sumatera-dataset"
WILDFIRE_SUMATERA_GEOTIFF_DIR = "wildfire-sumatera-geotiff"

LANDSAT_DIR = "landsat-8"

LANDSAT_8_FOLDER = f"{D_DIR}\\{WILDFIRE_SUMATERA_DATASET_DIR}\\{WILDFIRE_SUMATERA_GEOTIFF_DIR}\\{LANDSAT_DIR}"
LANDSAT_PREFIRE_FOLDER = f"{D_DIR}\\{WILDFIRE_SUMATERA_DATASET_DIR}\\{WILDFIRE_SUMATERA_GEOTIFF_DIR}\\{LANDSAT_DIR}\\prefire"
LANDSAT_POSTFIRE_FOLDER = f"{D_DIR}\\{WILDFIRE_SUMATERA_DATASET_DIR}\\{WILDFIRE_SUMATERA_GEOTIFF_DIR}\\{LANDSAT_DIR}\\postfire"

if D_DIR is not os.getcwd():
    os.chdir(D_DIR)
    print(f"OS directory is changed to {D_DIR}")
    print(os.getcwd())
    print()
    
if WILDFIRE_SUMATERA_DATASET_DIR not in os.listdir():
    os.mkdir(WILDFIRE_SUMATERA_DATASET_DIR)
    print(f"{WILDFIRE_SUMATERA_DATASET_DIR} has been created")
else:
    print(f"{WILDFIRE_SUMATERA_DATASET_DIR} already exist")
# Out:
# OS directory is changed to D:\
# D:\
#
# wildfire-sumatera-dataset already exist

# %%
# create folder for landsat-8 .tiff files
    
# check whether the folder is exists
if not os.path.exists(LANDSAT_PREFIRE_FOLDER):
    os.makedirs(LANDSAT_PREFIRE_FOLDER)
    print(f"{LANDSAT_PREFIRE_FOLDER} has been successfully create")
else:
    print(f"{LANDSAT_PREFIRE_FOLDER} already exist")

if not os.path.exists(LANDSAT_POSTFIRE_FOLDER):
    os.makedirs(LANDSAT_POSTFIRE_FOLDER)
    print(f"{LANDSAT_POSTFIRE_FOLDER} has been successfully create")
else:
    print(f"{LANDSAT_PREFIRE_FOLDER} already exist")
# Out:
# D:\\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\prefire already exist
# D:\\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\prefire already exist

# %%
# get list of url path for downloading .tiff files
download_landsat_satellite_image(
    satellite_name='LANDSAT/LC08/C02/T1_TOA', 
    situation='postfire',                                                                     
    dataset=sumatera_only, 
    scale=50, 
    file_format='GeoTIFF',
    folder_path=LANDSAT_POSTFIRE_FOLDER,
    )

print("done")
# Out:
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\0
# row 0 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\1
# row 1 requesting...
# download data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6b9cfc71dfd844eb1bf5a0417f412dea-5f53c79cee4eea7d9d08fd33cf63fdba:getPixels
# https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6b9cfc71dfd844eb1bf5a0417f412dea-5f53c79cee4eea7d9d08fd33cf63fdba:getPixels downloaded
# download data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0e7b0b44a778d185a4b8a2288a421e88-331f08fa47ab2d18f943b72a6162775b:getPixels
# https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0e7b0b44a778d185a4b8a2288a421e88-331f08fa47ab2d18f943b72a6162775b:getPixels downloaded
# download data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4420b776edc00bf86c1dca470787416a-510257544549f132e1b7750711446df2:getPixels
# https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4420b776edc00bf86c1dca470787416a-510257544549f132e1b7750711446df2:getPixels downloaded
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\2
# row 2 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\3
# row 3 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\4
# row 4 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5
# row 5 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\6
# row 6 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7
# row 7 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\8
# row 8 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\9
# row 9 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\10
# row 10 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\11
# row 11 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\12
# row 12 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\13
# row 13 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\14
# row 14 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\15
# row 15 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\16
# row 16 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\17
# row 17 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\18
# row 18 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\19
# row 19 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\20
# row 20 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\21
# row 21 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\22
# row 22 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\23
# row 23 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\24
# row 24 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\25
# row 25 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\26
# row 26 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\27
# row 27 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\28
# row 28 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\29
# row 29 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\30
# row 30 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\31
# row 31 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\32
# row 32 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\33
# row 33 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\34
# row 34 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\35
# row 35 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\36
# row 36 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\37
# row 37 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\38
# row 38 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\39
# row 39 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\40
# row 40 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\41
# row 41 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\42
# row 42 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\43
# row 43 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\44
# row 44 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\45
# row 45 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\46
# row 46 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\47
# row 47 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\48
# row 48 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\49
# row 49 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\50
# row 50 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\51
# row 51 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\52
# row 52 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\53
# row 53 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\54
# row 54 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\55
# row 55 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\56
# row 56 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\57
# row 57 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\58
# row 58 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\59
# row 59 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\60
# row 60 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\61
# row 61 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\62
# row 62 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\63
# row 63 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\64
# row 64 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\65
# row 65 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\66
# row 66 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\67
# row 67 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\68
# row 68 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\69
# row 69 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\70
# row 70 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\71
# row 71 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\72
# row 72 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\73
# row 73 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\74
# row 74 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\75
# row 75 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\76
# row 76 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\77
# row 77 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\78
# row 78 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\79
# row 79 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\80
# row 80 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\81
# row 81 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\82
# row 82 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\83
# row 83 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\84
# row 84 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\85
# row 85 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\86
# row 86 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\87
# row 87 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\88
# row 88 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\89
# row 89 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\90
# row 90 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\91
# row 91 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\92
# row 92 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\93
# row 93 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\94
# row 94 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\95
# row 95 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\96
# row 96 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\97
# row 97 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\98
# row 98 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\99
# row 99 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\100
# row 100 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\101
# row 101 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\102
# row 102 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\103
# row 103 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\104
# row 104 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\105
# row 105 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\106
# row 106 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\107
# row 107 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\108
# row 108 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\109
# row 109 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\110
# row 110 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\111
# row 111 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\112
# row 112 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\113
# row 113 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\114
# row 114 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\115
# row 115 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\116
# row 116 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\117
# row 117 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\118
# row 118 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\119
# row 119 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\120
# row 120 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\121
# row 121 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\122
# row 122 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\123
# row 123 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\124
# row 124 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\125
# row 125 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\126
# row 126 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\127
# row 127 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\128
# row 128 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\129
# row 129 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\130
# row 130 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\131
# row 131 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\132
# row 132 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\133
# row 133 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\134
# row 134 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\135
# row 135 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\136
# row 136 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\137
# row 137 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\138
# row 138 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\139
# row 139 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\140
# row 140 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\141
# row 141 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\142
# row 142 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\143
# row 143 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\144
# row 144 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\145
# row 145 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\146
# row 146 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\147
# row 147 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\148
# row 148 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\149
# row 149 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\150
# row 150 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\151
# row 151 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\152
# row 152 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\153
# row 153 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\154
# row 154 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\155
# row 155 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\156
# row 156 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\157
# row 157 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\158
# row 158 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\159
# row 159 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\160
# row 160 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\161
# row 161 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\162
# row 162 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\163
# row 163 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\164
# row 164 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\165
# row 165 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\166
# row 166 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\167
# row 167 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\168
# row 168 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\169
# row 169 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\170
# row 170 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\171
# row 171 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\172
# row 172 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\173
# row 173 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\174
# row 174 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\175
# row 175 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\176
# row 176 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\177
# row 177 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\178
# row 178 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\179
# row 179 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\180
# row 180 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\181
# row 181 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\182
# row 182 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\183
# row 183 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\184
# row 184 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\185
# row 185 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\186
# row 186 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\187
# row 187 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\188
# row 188 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\189
# row 189 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\190
# row 190 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\191
# row 191 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\192
# row 192 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\193
# row 193 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\194
# row 194 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\195
# row 195 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\196
# row 196 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\197
# row 197 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\198
# row 198 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\199
# row 199 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\200
# row 200 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\201
# row 201 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\202
# row 202 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\203
# row 203 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\204
# row 204 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\205
# row 205 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\206
# row 206 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\207
# row 207 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\208
# row 208 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\209
# row 209 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\210
# row 210 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\211
# row 211 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\212
# row 212 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\213
# row 213 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\214
# row 214 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\215
# row 215 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\216
# row 216 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\217
# row 217 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\218
# row 218 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\219
# row 219 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\220
# row 220 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\221
# row 221 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\222
# row 222 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\223
# row 223 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\224
# row 224 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\225
# row 225 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\226
# row 226 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\227
# row 227 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# ...
# row 7762 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7763
# row 7763 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7764
# row 7764 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7765
# row 7765 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7766
# row 7766 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7767
# row 7767 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7768
# row 7768 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7769
# row 7769 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7770
# row 7770 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7771
# row 7771 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7772
# row 7772 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7773
# row 7773 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7774
# row 7774 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7775
# row 7775 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7776
# row 7776 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7777
# row 7777 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7778
# row 7778 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7779
# row 7779 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7780
# row 7780 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7781
# row 7781 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7782
# row 7782 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7783
# row 7783 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7784
# row 7784 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7785
# row 7785 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7786
# row 7786 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7787
# row 7787 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7788
# row 7788 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7789
# row 7789 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7790
# row 7790 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7791
# row 7791 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7792
# row 7792 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7793
# row 7793 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7794
# row 7794 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7795
# row 7795 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7796
# row 7796 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7797
# row 7797 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7798
# row 7798 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7799
# row 7799 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7800
# row 7800 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7801
# row 7801 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7802
# row 7802 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7803
# row 7803 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7804
# row 7804 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7805
# row 7805 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7806
# row 7806 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7807
# row 7807 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7808
# row 7808 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7809
# row 7809 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7810
# row 7810 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7811
# row 7811 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7812
# row 7812 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7813
# row 7813 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7814
# row 7814 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7815
# row 7815 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7816
# row 7816 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7817
# row 7817 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7818
# row 7818 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7819
# row 7819 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7820
# row 7820 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7821
# row 7821 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7822
# row 7822 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7823
# row 7823 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7824
# row 7824 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7825
# row 7825 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7826
# row 7826 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7827
# row 7827 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7828
# row 7828 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7829
# row 7829 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7830
# row 7830 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7831
# row 7831 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7832
# row 7832 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7833
# row 7833 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7834
# row 7834 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7835
# row 7835 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7836
# row 7836 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7837
# row 7837 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# data already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7838
# row 7838 requesting...
# ['DELTA_NBR', 'B7'] already exist
# ['B5', 'B4'] already exist
# ['B3', 'B2'] already exist
# done

# %% [markdown]
# 1201 scale 60

# %%
# def get_filename(url):
#     """
#     Parses filename from given url
#     """
#     if url.find('/'):
#         temp = url.rsplit('/', 1)[1]
#         return temp.rsplit(':', 1)[0]
    
    
# def download_from_url_link(url_list, folder_path):
#     """
#     Download file using based on array of urls from parameter url_list
#     """
#     for i in range(len(url_list)):
# #         file_name = get_filename(url)
#         file_name = str(i)
#         file_path = os.path.join(folder_path, file_name)

#         if not os.path.exists(file_path):
#             print("Downloading...", file_name)
#             urllib.request.urlretrieve(url_list[i], file_path)

#     print('done')

# %%
# # download and make dataframe
# download_from_url_link(landsat_prefire_url_list, LANDSAT_PREFIRE_FOLDER)
# download_from_url_link(landsat_postfire_url_list, LANDSAT_POSTFIRE_FOLDER)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c099886be163> in <module>
#       1 # download and make dataframe
# ----> 2 download_from_url_link(landsat_prefire_url_list, LANDSAT_PREFIRE_FOLDER)
#       3 download_from_url_link(landsat_postfire_url_list, LANDSAT_POSTFIRE_FOLDER)
#
# NameError: name 'download_from_url_link' is not defined

# %%
# if 'wildfire_landsat_8_prefire.csv' not in os.listdir():
#     wildfire_df_prefire.to_csv('wildfire_landsat_8_prefire.csv')
    
# if 'wildfire_landsat_8_postfire.csv' not in os.listdir():
#     wildfire_df_postfire.to_csv('wildfire_landsat_8_postfire.csv')

# %% [markdown]
# # Create .csv file

# %%
metadata_prefire = pd.DataFrame({
    "file": [LANDSAT_PREFIRE_FOLDER+"\\{}".format(i) for i in range(len(sumatera_only))], 
    "class": [0 for i in range(len(sumatera_only))],
    }
)
metadata_prefire.head()

metadata_postfire = pd.DataFrame({
    "file": [LANDSAT_POSTFIRE_FOLDER+"\\{}".format(i) for i in range(len(sumatera_only))], 
    "class": [1 for i in range(len(sumatera_only))],
    }
)
metadata_postfire.head()

metadata = pd.concat([metadata_prefire, metadata_postfire], ignore_index=True)

# %%
if os.getcwd() is not LANDSAT_8_FOLDER:
    os.chdir(LANDSAT_8_FOLDER)
    metadata.to_csv("metadata.csv", index=False)
